# %% [markdown]
# <a href="https://colab.research.google.com/github/georgia-gatti/BTE320/blob/main/bte320_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5 + 3.0
# Out:
# 8.0

# %%
4-2
# Out:
# 2
